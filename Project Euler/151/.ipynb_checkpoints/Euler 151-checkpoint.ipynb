# %% [markdown]
# # A preference for A5
# This notebook solves the project Euler problem 151 - A preference for A5. The notebook performs the following steps:
# - Creates an envelope class (separate file)
# - Performs a tree search of all possible combinations of picking a piece of paper
# - Calculates the final result and prints

# %%
import pandas as pd

class Envelope:
    n_combinations = pd.DataFrame({'n_times_opened':range(16), 'was_a5':[0]*16, 'was_not_a5':[0]*16})
    
    def __init__(self, n_of_each=[1, 1, 1, 1], is_copy=False):   # Initialize envelope, n_of_each = [n_A2, n_A3, n_A4, n_A5]
        # assert (len(n_of_each) == 4) and (n_of_each[0].count(0) +  in ), f"x must be between 0 and {250}. Was {x}"
        # assert (x0 >= 0) and (x0 <= 250) and (x >= x0), f"x0 must be between 0 and {250} and be smaller than 'x'. Was {x0}"

        self.n_of_each = n_of_each
        self.n_times_opened = 0
        
        # Check if we are copying or initializing a new envelope. If it's new, update class variable
        # If we just want to copy something, don't do this
        if is_copy is False:
            self.n_combinations.loc[0,'was_not_a5'] = self.n_combinations.loc[0,'was_not_a5'] + 1

    def copy(self):
        out = Envelope(is_copy=True)
        out.n_of_each = self.n_of_each
        out.n_times_opened = self.n_times_opened
        return(out)

    def open_and_get_a5(self, ind):   # Open the envelope, get a piece of paper, cut until it is A5
        assert (isinstance(ind, int)) and (ind >= 0) and (ind <= 3), f"ind must be an integer between 0 and 3, was {ind}"
        
        if (self.n_of_each[ind] == 0):    # If we do not have any paper this size, do nothing
            pass
        else:
            # Update the times the envelope has been opened
            self.n_times_opened = self.n_times_opened + 1 

            n_of_each_new = self.n_of_each.copy()
            if ind == 3:   # We've picked an A5 from the start
                # Update stats
                self.n_combinations.loc[self.n_times_opened,'was_a5'] = self.n_combinations.loc[self.n_times_opened,'was_a5'] + 1
                
            else:          # We've picked something other than A5
                # Divide whatever we got and add one new to all subsequent sizes. In reality, for A5 we will add two and remove one, so delta=1
                for i in range(ind+1, 4):
                    n_of_each_new[i] = n_of_each_new[i]+1

                # Update stats
                self.n_combinations.loc[self.n_times_opened,'was_not_a5'] = self.n_combinations.loc[self.n_times_opened,'was_not_a5'] + 1

            # Update the object
            n_of_each_new[ind] = n_of_each_new[ind] - 1 
            self.n_of_each = n_of_each_new

    def __repr__(self):
        return f"{self.__class__.__name__}({self.n_of_each}, {self.n_times_opened})"

    def __str__(self):
        return('Number of times opened: ' + str(self.n_times_opened) + ', n_of_each: ' + str(self.n_of_each))

# %% [markdown]
# ______________
# ## Some tests

# %%
# e = Envelope()
# print(e)
# display(e.n_combinations[(e.n_combinations.was_a5 != 0) | (e.n_combinations.was_not_a5 != 0)])

# # Copying does not update class variable!
# e2 = e.copy()
# print(e2)
# display(e2.n_combinations[(e2.n_combinations.was_a5 != 0) | (e2.n_combinations.was_not_a5 != 0)])

# %%
# e = Envelope()

# print(e)
# display(e.n_combinations[(e.n_combinations.was_a5 != 0) | (e.n_combinations.was_not_a5 != 0)])

# e.open_and_get_a5(0)
# print(e)
# display(e.n_combinations[(e.n_combinations.was_a5 != 0) | (e.n_combinations.was_not_a5 != 0)])

# e.open_and_get_a5(3)
# print(e)
# display(e.n_combinations[(e.n_combinations.was_a5 != 0) | (e.n_combinations.was_not_a5 != 0)])

# e2 = Envelope()
# print(e2)
# display(e2.n_combinations[(e2.n_combinations.was_a5 != 0) | (e2.n_combinations.was_not_a5 != 0)])

# %%
# e = Envelope()
# print(e)
# e.open_and_get_a5(0)
# print(e)
# e.open_and_get_a5(1)
# print(e)
# e.open_and_get_a5(2)
# print(e)
# e.open_and_get_a5(2)
# print(e)
# e.open_and_get_a5(3)
# print(e)
# e.open_and_get_a5(3)
# print(e)
# e.open_and_get_a5(3)
# print(e)
# e.open_and_get_a5(3)
# print(e)

# %% [markdown]
# _______________
# ## Tree

# %%
# Go over the tree
env_list = [Envelope()]    # Initialize
# print(env_list)
done = False
while not done:
    # Take the last envelope (removing it from the list)
    # print(env_list)
    e = env_list.pop()
    # print(e)

    for i in range(4):
        if e.n_of_each[i] != 0:
            e_new = e.copy()
            e_new.open_and_get_a5(i)
            env_list.append(e_new)
            # print(env_list)

    # Check if the last envelope element is empty = Envelope([0, 0, 0, 0]). 
    # If it is, remove it
    while (len(env_list) > 0) and (env_list[-1].n_of_each == [0, 0, 0, 0]):
        env_list.pop()

    # See if we have anything left in the list - if not, then we're done
    if len(env_list) == 0:
        done = True

# %%
# Print answer
display(e.n_combinations)
n_not_a5 = e.n_combinations[~e.n_combinations.n_times_opened.isin([0, 15])].was_not_a5.sum()
n_a5 = e.n_combinations[~e.n_combinations.n_times_opened.isin([0, 15])].was_a5.sum()
n_tot = n_not_a5 + n_a5
print(n_a5, '/', n_tot, '=', round(n_a5/n_tot,6))
# Out:
#     n_times_opened  was_a5  was_not_a5
# 0                0       0           1
# 1                1       1           3
# 2                2       3           9
# 3                3      12          24
# 4                4      30          66
# 5                5      96         160
# 6                6     226         390
# 7                7     616         840
# 8                8    1288        1792
# 9                9    3080        3276
# 10              10    5600        5796
# 11              11   11396        8316
# 12              12   16016       12012
# 13              13   28028       12012
# 14              14   28028       12012
# 15              15   40040           0
# 94420 / 151128 = 0.624768

# %% [markdown]
# This is *not* the correct solution according to Project Euler! However, I have no idea what I've done wrong. Is the probabiklity of picking up a paper a function of its size? I've assumed the same probability for all, but perhaps that's not the case. Are you more likely to pick up a large piece of paper than a small one? Perhaps. Are you supposed to assume that? Not necessarily
